# %% [markdown]
# # Task 1: Exploring and Visualizing a Simple Dataset

# %% [markdown]
# ---
#
# ### 👨‍💻 **Author: Abdul Samad**
#
# - 🔗 **LinkedIn:**
#   [https://www.linkedin.com/in/abdulsamad577/](https://www.linkedin.com/in/abdulsamad577/)
#
# - 🧠 **Kaggle Profile:**
#   [https://www.kaggle.com/samad0015](https://www.kaggle.com/samad0015)
#
# ---

# %% [markdown]
# ## Introduction
# In this task, we will explore and visualize the **Iris dataset** using Python. The Iris dataset is a classic dataset in machine learning and statistics, often used for demonstrating data visualization techniques and classification algorithms.
#
# The **Iris dataset** is one of the most famous and widely used datasets in data science and machine learning. It contains information about **150 iris flowers**, collected from three different species:
#
# - *Iris setosa*
# - *Iris versicolor*
# - *Iris virginica*
#
# Each flower is described using **four features** (measured in centimeters):
#
# 1. **Sepal Length**
# 2. **Sepal Width**
# 3. **Petal Length**
# 4. **Petal Width**
#
# The dataset is often used for **classification tasks**, **visualization**, and **exploratory data analysis** (EDA) because it is clean, small, and easy to understand.

# %% [markdown]
# ### Objective
#
# - Understand how to load a dataset using Python.
# - Summarize key information using descriptive statistics.
# - Explore data patterns and distributions.
# - Create basic visualizations such as bar charts, histograms, and scatter plots.
# - Develop essential skills for analyzing and interpreting datasets effectively.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Load the Dataset

# %%
df=sns.load_dataset('iris')

# %% [markdown]
# ## Inspect the Dataset Structure

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# There are 150 rows and 5 columns in the dataset. The first four columns represent the features of the iris flowers, and the last column represents the species of each flower.

# %%
print("Column Names in the Dataset:")
for col in df.columns:
    print(f"- {col}")
# Out:
# Column Names in the Dataset:
# - sepal_length
# - sepal_width
# - petal_length
# - petal_width
# - species

# %% [markdown]
# The following table displays the first five rows of the Iris dataset using the `.head()` method. This is useful to quickly inspect the structure and sample data.

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# In these columns there are no missing values, and the data types are appropriate for analysis. The first four columns are numerical features, while the last column is categorical (species of iris flowers).

# %%
df.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# So we have 50 samples for each species, and the dataset is balanced.

# %% [markdown]
# ## Create Basic Visualizations

# %% [markdown]
# ### Scatter Plots:

# %% [markdown]
# #### Petal Length vs Petal Width

# %%
sns.scatterplot(data=df, x="petal_length", y="petal_width", hue="species")
plt.title("Scatter Plot of Petal Length vs Petal Width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Petal Length vs Sepal Width

# %%
sns.scatterplot(data=df, x="petal_length", y="sepal_width", hue="species")
plt.title("Scatter Plot of Petal Length vs Sepal Width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("sepal Width (cm)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Histograms of Iris Dataset Features
#
# The plots below display the distribution of the four main features of the Iris dataset:
#
# - **Sepal Length**
# - **Sepal Width**
# - **Petal Length**
# - **Petal Width**
#
# Each histogram shows how the values are distributed for that feature. The **KDE curve** (blue line) gives an estimate of the probability distribution. These plots help in understanding data spread, skewness, and patterns.

# %%
sns.set(style="whitegrid")
# List of feature names
features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
plt.figure(figsize=(12, 8))
# Loop to create histograms
for i, feature in enumerate(features):
    plt.subplot(2, 2, i+1)
    sns.histplot(data=df, x=feature, kde=True, color='skyblue')
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature.capitalize())
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Box Plots of Iris Dataset Features
#
# The box plots below visualize the **spread**, **central tendency**, and **potential outliers** for each numerical feature in the Iris dataset:
#
# - **Median** is shown by the line inside the box.
# - **Interquartile Range (IQR)** is represented by the box.
# - **Whiskers** extend to show the range, excluding outliers.
# - **Outliers** are shown as individual dots beyond the whiskers.
#
# These plots help in understanding the **distribution symmetry**, **spread**, and identifying any **unusual data points**.

# %%
plt.figure(figsize=(12, 8))
# List of features to plot
features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
# Create box plots for each feature
for i, feature in enumerate(features):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(data=df, y=feature, color='lightgreen')
    plt.title(f'Box Plot of {feature}')
    plt.ylabel(feature.capitalize())
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# In this task, we successfully explored and visualized the Iris dataset using Python libraries such as **Pandas**, **Matplotlib**, and **Seaborn**. We began by loading and inspecting the structure of the dataset, followed by creating meaningful visualizations to better understand the data.
#
# **Key takeaways from the task:**
#
# - We used `.shape`, `.columns`, and `.head()` to inspect the dataset's structure and content.
# - **Scatter plots** helped us explore relationships between different features.
# - **Histograms** revealed the distribution patterns of each feature.
# - **Box plots** allowed us to detect outliers and understand the spread of values.
#
# Overall, this task provided hands-on experience in **data loading, summarization, and visualization**, which are essential steps in any data analysis workflow. These foundational skills will be valuable for more advanced tasks such as machine learning, pattern recognition, and decision-making.
